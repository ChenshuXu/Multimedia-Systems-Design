# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

from scipy.fftpack import dct, idct
from numpy import pi
from numpy import sin
from numpy import zeros
from numpy import r_
from scipy import signal
from scipy import misc # pip install Pillow
import matplotlib.pylab as pylab

# %%
image = "188 180 155 149 179 116 86 96 \
168 179 168 174 180 111 86 95 \
150 166 175 189 165 101 88 97 \
163 165 179 184 135 90 91 96 \
170 180 178 144 102 87 91 98 \
175 174 141 104 85 83 88 96 \
153 134 105 82 83 87 92 96 \
117 104 86 80 86 90 92 103".split()
image = np.array(image, dtype=np.float64)
image
# Out:
# array([188., 180., 155., 149., 179., 116.,  86.,  96., 168., 179., 168.,
#        174., 180., 111.,  86.,  95., 150., 166., 175., 189., 165., 101.,
#         88.,  97., 163., 165., 179., 184., 135.,  90.,  91.,  96., 170.,
#        180., 178., 144., 102.,  87.,  91.,  98., 175., 174., 141., 104.,
#         85.,  83.,  88.,  96., 153., 134., 105.,  82.,  83.,  87.,  92.,
#         96., 117., 104.,  86.,  80.,  86.,  90.,  92., 103.])

# %%
def dct2(a):
    return dct(dct(a.T, norm='ortho').T, norm='ortho')

def idct2(a):
    return scipy.fftpack.idct( scipy.fftpack.idct( a, axis=0 , norm='ortho'), axis=1 , norm='ortho')

# %%
dct2_result = dct2(im)
dct2_result
# Out:
# array([176.57375785, 229.15096076, 228.89706262, 185.28772296,
#        228.37807817, 190.37268115, 143.82428293, 130.82043526,
#        195.27157929, 230.7869328 , 219.20462559, 205.354224  ,
#        222.28638196, 163.73270452, 121.96742989, 126.91163709,
#        178.33566078, 205.61503989, 203.44747272, 204.830492  ,
#        188.16807909, 117.57945614, 104.19728036, 115.69660664,
#        177.71139659, 186.57544255, 174.42901779, 172.35971035,
#        121.12509077,  71.30178781,  86.8409912 ,  98.91806253,
#        162.77750432, 164.23600266, 131.80518464,  92.03346721,
#         48.91718456,  46.17905497,  66.08484563,  78.45145995,
#        136.52390339, 111.83704331,  52.14055956,  21.26331051,
#         13.84999046,  27.80830315,  41.68039168,  52.04638533,
#         86.77136512,  43.06047759,   4.43596335,  -1.64126298,
#         10.07418829,  21.44962357,  24.06070471,  26.42878693,
#         31.90062105,   6.93008347,  -7.92207839,  -0.66936777,
# ...

# %%
image2 = "139,144,150,159,159,161,162,162,144,149,153,155,155,155,155,151,155,161,160,161,162,162,153,160,162,161,161,161,161,156,163,160,162,161,163,161,159,158,160,162,160,162,163,156,156,159,155,157,157,158,156,156,159,155,157,157,158,156,156,159,155,157,157,158".split(",")
image2 = np.array(image2, dtype=np.float64).reshape(8,8)
image2
# Out:
# array([[139., 144., 150., 159., 159., 161., 162., 162.],
#        [144., 149., 153., 155., 155., 155., 155., 151.],
#        [155., 161., 160., 161., 162., 162., 153., 160.],
#        [162., 161., 161., 161., 161., 156., 163., 160.],
#        [162., 161., 163., 161., 159., 158., 160., 162.],
#        [160., 162., 163., 156., 156., 159., 155., 157.],
#        [157., 158., 156., 156., 159., 155., 157., 157.],
#        [158., 156., 156., 159., 155., 157., 157., 158.]])

# %%
dcts2 = dct2(image2)
print(dcts2)
# Out:
# [[ 1.25962500e+03 -6.70048095e+00 -5.64375576e+00 -4.08770304e+00
#   -1.25000000e-01 -9.53074809e-01 -2.32961299e-01 -5.46248386e-01]
#  [-8.49822493e+00 -1.49217435e+01 -9.97547394e+00 -1.47957606e+00
#   -6.03574604e-01 -2.38195551e-01 -9.23559988e-01 -1.12143822e+00]
#  [-1.76377752e+01 -1.41099119e+01 -5.78813582e+00  1.10038338e+00
#    4.33918421e-01  1.65814662e+00 -7.43718434e-01 -2.57604302e+00]
#  [-2.57123497e+00 -5.55950120e+00  1.01202821e-01 -9.96994568e-01
#   -2.12786631e+00  9.63666362e-01  1.00071917e+00  1.20328759e+00]
#  [ 6.12500000e+00 -6.43985466e+00  2.32130565e+00 -1.19116949e+00
#    2.87500000e+00  5.38923922e+00 -1.90860946e+00  3.57753867e-01]
#  [ 4.68414195e+00 -3.30684098e+00  3.65148260e-01  9.33336276e-01
#    2.09820959e+00 -1.25516093e+00 -2.63684341e+00  1.32958609e+00]
#  [ 6.08811445e+00  5.38947944e-01 -4.93718434e-01 -5.71925414e-01
#   -5.85631970e-01 -3.26110247e+00  4.28813582e+00 -3.66561609e+00]
# ...
